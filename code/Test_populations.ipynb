# %%
import numpy as np
from algorithms import UtilityMatrix
from agents import Population
from rewards import RewardFunctionExponential, RewardFunctionSquaredExponential
from samplersRecommendation import UniformSamplerRecommendation
from parameters import ParametersUser, ParametersPopulation
from utils import Opinion, ListOpinion
from simulator import Simulator

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=3)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.3,
                              weight_current_opinion=0.7,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 28>()
#      24 simulator_identical = Simulator(agent=population_identical,
#      25                                 algorithm=alg_identical)
#      27 # Run
# ---> 28 simulator_identical.run(horizon=1000)
#      30 # Plot
#      31 simulator_identical.agent.plot(save=False, name='sim_identical')
#
# File ~/Desktop/Projects/Recommender Systems/code/simulator.py:19, in Simulator.run(self, horizon)
#      16 for t in range(0, horizon):
#      17     r = self.algorithm.compute_recommendation(reward=reward,
#      18                                               time=t)
# ---> 19     reward = self.agent.update_state(recommendation=r)
#
# File ~/Desktop/Projects/Recommender Systems/code/agents.py:118, in Population.update_state(self, recommendation)
#     116 self._x = self.get_opinion_vector()
#     117 if self.save_history:
# --> 118     self.trajectory.append(keys=[KEY_OPINION, KEY_REWARD, KEY_RECOMMENDATION, KEY_AVERAGE_OPINION,
#     119                                  KEY_STD_OPINION, KEY_AVERAGE_REWARD, KEY_AVERAGE_RECOMMENDATION],
#     120                            items=[self.get_opinion_vector(), reward, recommendation, self.average_opinion(),
#     121                                   self.std_opinion(), np.mean(reward), np.mean(recommendation)])
#     122 return reward
#
# File ~/Desktop/Projects/Recommender Systems/code/trajectory.py:42, in Trajectory.append(self, keys, items)
#      40     assert len(items) == len(keys), 'items should have the same length as keys.'
#      41     for i, k in enumerate(keys):
# ---> 42         self.add_item(key=k, item=items[i])
#      43 elif isinstance(keys, str):
#      44     self.add_item(key=keys, item=items)
#
# File ~/Desktop/Projects/Recommender Systems/code/trajectory.py:35, in Trajectory.add_item(self, key, item)
#      33 else:
#      34     assert(self.get_item(key=key).shape[1] == item.shape[1]), 'The size must coincide.'
# ---> 35     self._trajectory[key] = np.concatenate((self.get_item(key), item), axis=0)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.01,
                              weight_current_opinion=0.99,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.5,
                              weight_current_opinion=0.5,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.5,
                              weight_current_opinion=0.5,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=2)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=0, high=0, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=1000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.8, high=-0.8, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)
recommendation_sampler_1 = UniformSamplerRecommendation(low=-1.0, high=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-1.0, high=1.0, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              recommendation_sampler=recommendation_sampler_1,
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical
