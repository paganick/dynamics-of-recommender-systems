# %%
import numpy as np
from algorithms import UtilityMatrix
from agents import Population
from rewards import RewardFunctionExponential, RewardFunctionSquaredExponential
from parameters import ParametersUser, ParametersPopulation
from utils import Opinion, ListOpinion
from simulator import Simulator

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=3)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.3,
                              weight_current_opinion=0.7,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.01,
                              weight_current_opinion=0.99,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.5,
                              weight_current_opinion=0.5,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.5,
                              weight_current_opinion=0.5,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.2, high=0.2, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=2)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=0, high=0, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=1000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-0.8, high=-0.8, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical

# %%
reward_1 = RewardFunctionSquaredExponential(decay_parameter=1.0)

parameters_1 = ParametersUser(prejudice=Opinion(0.0),
                              weight_prejudice=0.0,
                              weight_recommendation=0.1,
                              weight_current_opinion=0.9,
                              reward=reward_1)

parameters_population_identical = ParametersPopulation(parameters=parameters_1,
                                                       repeat=10000)

# Define population
population_identical = Population(initial_state=ListOpinion(np.random.uniform(low=-1.0, high=1.0, size=10000)),
                                  parameters=parameters_population_identical,
                                  save_history=True)

# Define algorithm
alg_identical = UtilityMatrix(n_agents=population_identical.n_agents(),
                              exploration_probability=None,
                              exploration_frequency=10)
# Simulators
simulator_identical = Simulator(agent=population_identical,
                                algorithm=alg_identical)

# Run
simulator_identical.run(horizon=1000)

# Plot
simulator_identical.agent.plot(save=False, name='sim_identical')

del reward_1, parameters_1, parameters_population_identical, population_identical, alg_identical, simulator_identical
